# %% [markdown]
# # Hugging Face and Transformers — Colab
#
# This notebook mirrors `docs/chapter_llm_ft/hg_transformers.md`. You will:
# - Install and use `transformers`, `datasets`, `accelerate`
# - Load a tokenizer and model (DistilBERT) and tokenize inputs
# - Create small batches, inspect attention masks and outputs
# - Train briefly via DataLoader and via `Trainer`
#
# All demos are sized to run within free Colab limits.

# %%
# Install libraries for Transformers intro
import sys, subprocess

def pip_install(packages):
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "--upgrade", *packages])

pip_install([
    "torch",
    "transformers",
    "datasets",
    "accelerate",
    "scikit-learn",
])

import torch, transformers, datasets, accelerate
print("torch:", torch.__version__)
print("transformers:", transformers.__version__)
print("datasets:", datasets.__version__)

# %% [markdown]
# ## Load tokenizer and model (DistilBERT)
#
# We’ll start with a small encoder model and explore tokenization and tensors.

# %%
from transformers import AutoTokenizer, AutoModel

model_name = "distilbert/distilbert-base-cased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
print(tokenizer)
print(model.__class__.__name__)
